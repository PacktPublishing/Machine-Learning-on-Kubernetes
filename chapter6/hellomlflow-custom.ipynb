# %% [markdown]
# # Notebook to verify Mlflow

# %% [markdown]
# ## Import mlflow library

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import mlflow
import os

import mlflow_util

# %% [markdown]
# ## Prepare training data

# %%
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
y = np.dot(X, np.array([1, 2])) + 3

# %% [markdown]
# ## Setup Mlflow
# You will put the location of Mlflow server. Note that becuase your notebook and the Mlflow server is running on Kubernetes, we just put the location of Kubernetes Service.
#
# We are using our local Minio server as the S3 storage and therefore pass the variables named AWS_SECRET_ACCESS_KEY containing the password.
#
# ### Experiment Name
# This is one important variable via which all of your experiment runs will be stored in the Mlflow server

# %%
HOST = "http://mlflow:5500"

EXPERIMENT_NAME = "HelloMlFlowCustom"

os.environ['MLFLOW_S3_ENDPOINT_URL']='http://minio-ml-workshop:9000'
os.environ['AWS_ACCESS_KEY_ID']='minio'
# os.environ['AWS_SECRET_ACCESS_KEY']='minio123'
os.environ['AWS_REGION']='us-east-1'
os.environ['AWS_BUCKET_NAME']='mlflow'

# Connect to local MLflow tracking server
mlflow.set_tracking_uri(HOST)

# Set the experiment name through which you will label all your exerpiments runs
mlflow.set_experiment(EXPERIMENT_NAME)

# enable autologging for scikit
mlflow.sklearn.autolog()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1255         """Send a complete request to the server."""
# -> 1256         self._send_request(method, url, body, headers, encode_chunked)
#    1257
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1301             body = _encode(body, 'body')
# -> 1302         self.endheaders(body, encode_chunked=encode_chunked)
#    1303
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1250             raise CannotSendHeader()
# -> 1251         self._send_output(message_body, encode_chunked=encode_chunked)
#    1252
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1010         del self._buffer[:]
# -> 1011         self.send(msg)
#    1012
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in send(self, data)
#     950             if self.auto_open:
# --> 951                 self.connect()
#     952             else:
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x16c3df130>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='mlflow', port=5500): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=HelloMlFlowCustom (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16c3df130>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in http_request(host_creds, endpoint, method, max_retries, backoff_factor, retry_codes, timeout, **kwargs)
#     133     try:
# --> 134         return _get_http_response_with_retries(
#     135             method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in _get_http_response_with_retries(method, url, max_retries, backoff_factor, retry_codes, **kwargs)
#      73         http.mount("http://", adapter)
# ---> 74         response = http.request(method, url, **kwargs)
#      75         return response
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPConnectionPool(host='mlflow', port=5500): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=HelloMlFlowCustom (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16c3df130>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py in get_experiment_by_name(self, experiment_name)
#     277             req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 278             response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     279             return Experiment.from_proto(response_proto.experiment)
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py in _call_endpoint(self, api, json_body)
#      55         response_proto = api.Response()
# ---> 56         return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#      57
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     209     if method == "GET":
# --> 210         response = http_request(
#     211             host_creds=host_creds, endpoint=endpoint, method=method, params=json_body
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in http_request(host_creds, endpoint, method, max_retries, backoff_factor, retry_codes, timeout, **kwargs)
#     145     except Exception as e:
# --> 146         raise MlflowException("API request to %s failed with exception %s" % (url, e))
#     147
#
# MlflowException: API request to http://mlflow:5500/api/2.0/mlflow/experiments/get-by-name failed with exception HTTPConnectionPool(host='mlflow', port=5500): Max retries exceeded with url: /api/2.0/mlflow/experiments/get-by-name?experiment_name=HelloMlFlowCustom (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16c3df130>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1255         """Send a complete request to the server."""
# -> 1256         self._send_request(method, url, body, headers, encode_chunked)
#    1257
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1301             body = _encode(body, 'body')
# -> 1302         self.endheaders(body, encode_chunked=encode_chunked)
#    1303
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1250             raise CannotSendHeader()
# -> 1251         self._send_output(message_body, encode_chunked=encode_chunked)
#    1252
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1010         del self._buffer[:]
# -> 1011         self.send(msg)
#    1012
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/http/client.py in send(self, data)
#     950             if self.auto_open:
# --> 951                 self.connect()
#     952             else:
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x16c3eb3a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='mlflow', port=5500): Max retries exceeded with url: /api/2.0/mlflow/experiments/list?view_type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16c3eb3a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in http_request(host_creds, endpoint, method, max_retries, backoff_factor, retry_codes, timeout, **kwargs)
#     133     try:
# --> 134         return _get_http_response_with_retries(
#     135             method,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in _get_http_response_with_retries(method, url, max_retries, backoff_factor, retry_codes, **kwargs)
#      73         http.mount("http://", adapter)
# ---> 74         response = http.request(method, url, **kwargs)
#      75         return response
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPConnectionPool(host='mlflow', port=5500): Max retries exceeded with url: /api/2.0/mlflow/experiments/list?view_type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16c3eb3a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# <ipython-input-9-2c865800126d> in <module>
#      13
#      14 # Set the experiment name through which you will label all your exerpiments runs
# ---> 15 mlflow.set_experiment(EXPERIMENT_NAME)
#      16
#      17 # enable autologging for scikit
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/tracking/fluent.py in set_experiment(experiment_name)
#      82     """
#      83     client = MlflowClient()
# ---> 84     experiment = client.get_experiment_by_name(experiment_name)
#      85     exp_id = experiment.experiment_id if experiment else None
#      86     if exp_id is None:  # id can be 0
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/tracking/client.py in get_experiment_by_name(self, name)
#     460             Lifecycle_stage: active
#     461         """
# --> 462         return self._tracking_client.get_experiment_by_name(name)
#     463
#     464     def create_experiment(self, name: str, artifact_location: Optional[str] = None) -> str:
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py in get_experiment_by_name(self, name)
#     161         :return: :py:class:`mlflow.entities.Experiment`
#     162         """
# --> 163         return self.store.get_experiment_by_name(name)
#     164
#     165     def create_experiment(self, name, artifact_location=None):
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py in get_experiment_by_name(self, experiment_name)
#     288                 raise e
#     289             # Fall back to using ListExperiments-based implementation.
# --> 290             for experiment in self.list_experiments(ViewType.ALL):
#     291                 if experiment.name == experiment_name:
#     292                     return experiment
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py in list_experiments(self, view_type, max_results, page_token)
#      72             ListExperiments(view_type=view_type, max_results=max_results, page_token=page_token)
#      73         )
# ---> 74         response_proto = self._call_endpoint(ListExperiments, req_body)
#      75         experiments = [Experiment.from_proto(x) for x in response_proto.experiments]
#      76         # If the response doesn't contain `next_page_token`, `response_proto.next_page_token`
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/store/tracking/rest_store.py in _call_endpoint(self, api, json_body)
#      54         endpoint, method = _METHOD_TO_INFO[api]
#      55         response_proto = api.Response()
# ---> 56         return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#      57
#      58     def list_experiments(
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     208         json_body = json.loads(json_body)
#     209     if method == "GET":
# --> 210         response = http_request(
#     211             host_creds=host_creds, endpoint=endpoint, method=method, params=json_body
#     212         )
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/mlflow/utils/rest_utils.py in http_request(host_creds, endpoint, method, max_retries, backoff_factor, retry_codes, timeout, **kwargs)
#     144         )
#     145     except Exception as e:
# --> 146         raise MlflowException("API request to %s failed with exception %s" % (url, e))
#     147
#     148
#
# MlflowException: API request to http://mlflow:5500/api/2.0/mlflow/experiments/list failed with exception HTTPConnectionPool(host='mlflow', port=5500): Max retries exceeded with url: /api/2.0/mlflow/experiments/list?view_type=ALL (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x16c3eb3a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# ## Perform training as usual

# %%
model = DecisionTreeClassifier(max_depth=5, criterion='gini',min_samples_leaf = 3 ,min_samples_split = 10)

# %% [markdown]
# # Adding custom tags to the run
# Mlflow api allows to associate the custom tags as shown below.
#
# record_libraries is a custom function which runs the pip freeze command and store it as a file to the mlflow run. You can find this function in the associated mlflow_util class in this repo.

# %%
with mlflow.start_run(tags={
    "mlflow.source.git.commit" : mlflow_util.get_git_revision_hash() ,
    "mlflow.source.git.branch": mlflow_util.get_git_branch(),
    "code.repoURL": mlflow_util.get_git_remote()
    }) as run:
    
    model.fit(X, y)
    mlflow_util.record_libraries(mlflow)
    mlflow_util.log_metrics("custom_mteric", "custom_value")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-156ddb4892db> in <module>
#       1 with mlflow.start_run(tags={
# ----> 2     "mlflow.source.git.commit" : get_git_revision_hash() ,
#       3     "mlflow.source.git.branch": get_git_branch(),
#       4     "mlflow.source.type": "NOTEBOOK",
#       5     "mlflow.source.git.repoURL": get_git_remote()
#
# NameError: name 'get_git_revision_hash' is not defined
